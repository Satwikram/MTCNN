# %% [markdown]
# <a href="https://colab.research.google.com/github/Satwikram/MTCNN/blob/main/MTCNN%20From%20Folders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Author: Satwik Ram K
#
# Method: Applying MTCNN to the images in Folder

# %% [markdown]
# ### Unzip the Image Folder

# %%
# !unzip /content/test.zip
# Out:
# Archive:  /content/test.zip
#   inflating: test/download-1.jpg
#  extracting: test/download-2.jpg
#   inflating: test/download-3.jpg
#   inflating: test/download-4.jpg
#   inflating: test/download.jpg
#   inflating: test/images-1.jpg
#   inflating: test/images.jpg

# %%
# !pip install mtcnn
# Out:
# ...
#      |████████████████████████████████| 2.3MB 5.4MB/s
# ...

# %%
# !pip show mtcnn
# Out:
# Name: mtcnn
# Version: 0.1.0
# Summary: Multi-task Cascaded Convolutional Neural Networks for Face Detection, based on TensorFlow
# Home-page: http://github.com/ipazc/mtcnn
# Author: Iván de Paz Centeno
# Author-email: ipazc@unileon.es
# License: MIT
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: opencv-python, keras
# Required-by:

# %%
# confirm mtcnn was installed correctly
import mtcnn
# print version
print(mtcnn.__version__)
# Out:
# 0.1.0

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt

# %%
from mtcnn.mtcnn import MTCNN
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle

# %%
def draw_faces(filename, result_list):
	# load the image
	data = plt.imread(filename)
	# plot each face as a subplot
	for i in range(len(result_list)):
		# get coordinates
		x1, y1, width, height = result_list[i]['box']
		x2, y2 = x1 + width, y1 + height
		# define subplot
		plt.subplot(1, len(result_list), i+1)
		plt.axis('off')
		# plot face
		plt.imshow(data[y1:y2, x1:x2])
		filename = 'face'+str(i)+'.jpg'
		cv2.imwrite(filename, data[y1:y2, x1:x2])
	# show the plot
	plt.show()

# %%
for img in os.listdir('/content/test'):
  filename = os.path.join('/content/test', img)
  img = plt.imread(os.path.join('/content/test', img))
  plt.imshow(img)
  detector = MTCNN()
  # detect faces in the image
  faces = detector.detect_faces(img)
  draw_faces(filename, faces)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f91589e6b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
img = cv2.imread('/content/test/download-1.jpg')
img = cv2.resize(img, (640, 480))

# %%
plt.imshow(img)
